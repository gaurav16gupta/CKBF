# %%
bf_size = [1000000, 10000000, 100000000, 1000000000, 2000000000]
murmurhash_time = [118422, 117691, 118133, 119522, 117138]
query_time = [43948, 47380, 161172, 312254, 374733]

# %%
import matplotlib.pyplot as plt

plt.figure(dpi=300)
plt.plot(bf_size, murmurhash_time, '.-', label='murmur hash time')
plt.plot(bf_size, query_time, '.-', label='BF lookup time')
plt.axhline(y=153717, color='r', linestyle='-', label='xxhash time')
plt.legend()
plt.xlabel('BF size')
plt.ylabel('microseconds')
plt.savefig('bf_time.png')
# Out:
# Text(0, 0.5, 'microseconds')
